# %%
import matplotlib.pyplot as plt
from matplotlib import style
from itertools import cycle

import numpy as np
import pandas as pd
from sklearn.cluster import KMeans, MeanShift, AffinityPropagation, estimate_bandwidth
from sklearn import preprocessing
from sklearn.preprocessing import scale
from sklearn import metrics

# %%
df = pd.read_csv('./Wholesale_customers_data.csv')
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
dfx = df.drop(['Channel'], axis=1).astype(float)
X = np.array(dfx)
X = scale(X)
Y = np.array(df['Channel'])

# %%
n_clusters_km = 2 # predefined number for clusters

km = KMeans(n_clusters=n_clusters_km)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
for i in range(len(X)):
    predict_me = np.array(X[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = clf.predict(predict_me)
    if prediction[0] == Y[i]:
        correct+=1
        
print(correct/len(X) * 100)
# Out:
# 1.3636363636363635

# %%
af = AffinityPropagation(damping=0.9)
af.fit(X)
cluster_centers_indices_af = af.cluster_centers_indices_
labels_af = af.labels_

n_clusters_af = len(cluster_centers_indices_af)

# %%
plt.figure(2)
plt.clf()
###### Code from scikit-learn.org ######
colors = cycle('bgrcmyk')
for k, col in zip(range(n_clusters_af), colors):
    class_members = labels == k
    cluster_center = X[cluster_centers_indices_af[k]]
    plt.plot(X[class_members, 0], X[class_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=2)
    for x in X[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Number of clusters with AffinityPropagation: %d' % n_clusters_af)
# Out:
# Text(0.5,1,'Number of clusters with AffinityPropagation: 42')

# %%
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=200)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)
# Out:
# MeanShift(bandwidth=1.9921489195373527, bin_seeding=True, cluster_all=True,
#      min_bin_freq=1, n_jobs=1, seeds=None)

# %%
labels_ms = ms.labels_
cluster_centers_ms = ms.cluster_centers_

labels_unique_ms = np.unique(labels)
n_clusters_ms = len(labels_unique)

# %%
plt.figure(3)
plt.clf()

###### Code from scikit-learn.org ######
colors = cycle('bgrcmyk')
for k, col in zip(range(n_clusters_ms), colors):
    my_members = labels_ms == k
    cluster_center = cluster_centers_ms[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=2)
plt.title('Number of clusters with Mean Shift: %d' % n_clusters_ms)
# Out:
# Text(0.5,1,'Number of clusters with Mean Shift: 18')
